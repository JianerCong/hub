# %%
s = """<li class="ListItem--gZsmL"><section data-testid="toc-primaryexpressions" class="TOCItem--dKWRM" aria-current="false"><article class="titleSection--UBioc"><h6 class="TOCTitle--fFPXo"><a class="orm-Link-root" href="/library/view/javascript-the-definitive/9781491952016/ch04.html#primaryexpressions">4.1 Primary Expressions</a></h6></article></section></li><li class="ListItem--gZsmL"><section data-testid="toc-initializerexprs" class="TOCItem--dKWRM" aria-current="false"><article class="titleSection--UBioc"><h6 class="TOCTitle--fFPXo"><a class="orm-Link-root" href="/library/view/javascript-the-definitive/9781491952016/ch04.html#initializerexprs">4.2 Object and Array Initializers</a></h6></article></section></li><li class="ListItem--gZsmL"><section data-testid="toc-functionexprs" class="TOCItem--dKWRM" aria-current="false"><article class="titleSection--UBioc"><h6 class="TOCTitle--fFPXo"><a class="orm-Link-root" href="/library/view/javascript-the-definitive/9781491952016/ch04.html#functionexprs">4.3 Function Definition Expressions</a></h6></article></section></li><li class="ListItem--gZsmL"><div class="ToggleWrapper--d7435"><section data-testid="toc-propertyexprs" class="TOCItem--dKWRM" aria-current="false"><article class="titleSection--UBioc"><h6 class="TOCTitle--fFPXo"><a class="orm-Link-root" href="/library/view/javascript-the-definitive/9781491952016/ch04.html#propertyexprs">4.4 Property Access Expressions</a></h6></article></section><button class="Toggle--WhBCg" role="button" title="Show More Items"><span class="orm-Icon-root" style="height: 1rem;" data-testid="icon"><span style="font-size: 1rem; width: 1rem; height: 1rem;" class="orm-Icon-icon orm-icon-chevron-down " aria-hidden="true"></span><span class="orm-Icon-title">Show More Items</span></span></button></div></li><li class="ListItem--gZsmL"><div class="ToggleWrapper--d7435"><section data-testid="toc-invocationexprs" class="TOCItem--dKWRM" aria-current="false"><article class="titleSection--UBioc"><h6 class="TOCTitle--fFPXo"><a class="orm-Link-root" href="/library/view/javascript-the-definitive/9781491952016/ch04.html#invocationexprs">4.5 Invocation Expressions</a></h6></article></section><button class="Toggle--WhBCg" role="button" title="Show More Items"><span class="orm-Icon-root" style="height: 1rem;" data-testid="icon"><span style="font-size: 1rem; width: 1rem; height: 1rem;" class="orm-Icon-icon orm-icon-chevron-down " aria-hidden="true"></span><span class="orm-Icon-title">Show More Items</span></span></button></div></li><li class="ListItem--gZsmL"><section data-testid="toc-newexprs" class="TOCItem--dKWRM" aria-current="false"><article class="titleSection--UBioc"><h6 class="TOCTitle--fFPXo"><a class="orm-Link-root" href="/library/view/javascript-the-definitive/9781491952016/ch04.html#newexprs">4.6 Object Creation Expressions</a></h6></article></section></li><li class="ListItem--gZsmL"><div class="ToggleWrapper--d7435"><section data-testid="toc-I_sect13_d1e5618" class="TOCItem--dKWRM" aria-current="false"><article class="titleSection--UBioc"><h6 class="TOCTitle--fFPXo"><a class="orm-Link-root" href="/library/view/javascript-the-definitive/9781491952016/ch04.html#I_sect13_d1e5618">4.7 Operator Overview</a></h6></article></section><button class="Toggle--WhBCg" role="button" title="Show More Items"><span class="orm-Icon-root" style="height: 1rem;" data-testid="icon"><span style="font-size: 1rem; width: 1rem; height: 1rem;" class="orm-Icon-icon orm-icon-chevron-down " aria-hidden="true"></span><span class="orm-Icon-title">Show More Items</span></span></button></div></li><li class="ListItem--gZsmL"><div class="ToggleWrapper--d7435"><section data-testid="toc-arithmeticoperators" class="TOCItem--dKWRM" aria-current="false"><article class="titleSection--UBioc"><h6 class="TOCTitle--fFPXo"><a class="orm-Link-root" href="/library/view/javascript-the-definitive/9781491952016/ch04.html#arithmeticoperators">4.8 Arithmetic Expressions</a></h6></article></section><button class="Toggle--WhBCg" role="button" title="Show More Items"><span class="orm-Icon-root" style="height: 1rem;" data-testid="icon"><span style="font-size: 1rem; width: 1rem; height: 1rem;" class="orm-Icon-icon orm-icon-chevron-down " aria-hidden="true"></span><span class="orm-Icon-title">Show More Items</span></span></button></div></li><li class="ListItem--gZsmL"><div class="ToggleWrapper--d7435"><section data-testid="toc-relationalexprs" class="TOCItem--dKWRM" aria-current="false"><article class="titleSection--UBioc"><h6 class="TOCTitle--fFPXo"><a class="orm-Link-root" href="/library/view/javascript-the-definitive/9781491952016/ch04.html#relationalexprs">4.9 Relational Expressions</a></h6></article></section><button class="Toggle--WhBCg" role="button" title="Show More Items"><span class="orm-Icon-root" style="height: 1rem;" data-testid="icon"><span style="font-size: 1rem; width: 1rem; height: 1rem;" class="orm-Icon-icon orm-icon-chevron-down " aria-hidden="true"></span><span class="orm-Icon-title">Show More Items</span></span></button></div></li><li class="ListItem--gZsmL"><div class="ToggleWrapper--d7435"><section data-testid="toc-logicalexprs" class="TOCItem--dKWRM" aria-current="false"><article class="titleSection--UBioc"><h6 class="TOCTitle--fFPXo"><a class="orm-Link-root" href="/library/view/javascript-the-definitive/9781491952016/ch04.html#logicalexprs">4.10 Logical Expressions</a></h6></article></section><button class="Toggle--WhBCg" role="button" title="Show More Items"><span class="orm-Icon-root" style="height: 1rem;" data-testid="icon"><span style="font-size: 1rem; width: 1rem; height: 1rem;" class="orm-Icon-icon orm-icon-chevron-down " aria-hidden="true"></span><span class="orm-Icon-title">Show More Items</span></span></button></div></li><li class="ListItem--gZsmL"><div class="ToggleWrapper--d7435"><section data-testid="toc-I_sect13_d1e8479" class="TOCItem--dKWRM" aria-current="false"><article class="titleSection--UBioc"><h6 class="TOCTitle--fFPXo"><a class="orm-Link-root" href="/library/view/javascript-the-definitive/9781491952016/ch04.html#I_sect13_d1e8479">4.11 Assignment Expressions</a></h6></article></section><button class="Toggle--WhBCg" role="button" title="Show More Items"><span class="orm-Icon-root" style="height: 1rem;" data-testid="icon"><span style="font-size: 1rem; width: 1rem; height: 1rem;" class="orm-Icon-icon orm-icon-chevron-down " aria-hidden="true"></span><span class="orm-Icon-title">Show More Items</span></span></button></div></li><li class="ListItem--gZsmL"><div class="ToggleWrapper--d7435"><section data-testid="toc-evalexprs" class="TOCItem--dKWRM" aria-current="false"><article class="titleSection--UBioc"><h6 class="TOCTitle--fFPXo"><a class="orm-Link-root" href="/library/view/javascript-the-definitive/9781491952016/ch04.html#evalexprs">4.12 Evaluation Expressions</a></h6></article></section><button class="Toggle--WhBCg" role="button" title="Show More Items"><span class="orm-Icon-root" style="height: 1rem;" data-testid="icon"><span style="font-size: 1rem; width: 1rem; height: 1rem;" class="orm-Icon-icon orm-icon-chevron-down " aria-hidden="true"></span><span class="orm-Icon-title">Show More Items</span></span></button></div></li><li class="ListItem--gZsmL"><div class="ToggleWrapper--d7435"><section data-testid="toc-I_sect13_d1e9018" class="TOCItem--dKWRM" aria-current="false"><article class="titleSection--UBioc"><h6 class="TOCTitle--fFPXo"><a class="orm-Link-root" href="/library/view/javascript-the-definitive/9781491952016/ch04.html#I_sect13_d1e9018">4.13 Miscellaneous Operators</a></h6></article></section><button class="Toggle--WhBCg" role="button" title="Show More Items"><span class="orm-Icon-root" style="height: 1rem;" data-testid="icon"><span style="font-size: 1rem; width: 1rem; height: 1rem;" class="orm-Icon-icon orm-icon-chevron-down " aria-hidden="true"></span><span class="orm-Icon-title">Show More Items</span></span></button></div></li><li class="ListItem--gZsmL"><section data-testid="toc-idm46198556939320" class="TOCItem--dKWRM" aria-current="false"><article class="titleSection--UBioc"><h6 class="TOCTitle--fFPXo"><a class="orm-Link-root" href="/library/view/javascript-the-definitive/9781491952016/ch04.html#idm46198556939320">4.14 Summary</a></h6></article></section></li>
"""

s
# Out:
# '<li class="ListItem--gZsmL"><section data-testid="toc-primaryexpressions" class="TOCItem--dKWRM" aria-current="false"><article class="titleSection--UBioc"><h6 class="TOCTitle--fFPXo"><a class="orm-Link-root" href="/library/view/javascript-the-definitive/9781491952016/ch04.html#primaryexpressions">4.1 Primary Expressions</a></h6></article></section></li><li class="ListItem--gZsmL"><section data-testid="toc-initializerexprs" class="TOCItem--dKWRM" aria-current="false"><article class="titleSection--UBioc"><h6 class="TOCTitle--fFPXo"><a class="orm-Link-root" href="/library/view/javascript-the-definitive/9781491952016/ch04.html#initializerexprs">4.2 Object and Array Initializers</a></h6></article></section></li><li class="ListItem--gZsmL"><section data-testid="toc-functionexprs" class="TOCItem--dKWRM" aria-current="false"><article class="titleSection--UBioc"><h6 class="TOCTitle--fFPXo"><a class="orm-Link-root" href="/library/view/javascript-the-definitive/9781491952016/ch04.html#function
# ...
